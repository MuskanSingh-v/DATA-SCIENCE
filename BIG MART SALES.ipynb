# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

# %%
df=pd.read_csv("train_bm.csv")

# %%
df.head()
# Out:
#   Item_Identifier  Item_Weight Item_Fat_Content  Item_Visibility  \
# 0           FDA15         9.30          Low Fat         0.016047
# 1           DRC01         5.92          Regular         0.019278
# 2           FDN15        17.50          Low Fat         0.016760
# 3           FDX07        19.20          Regular         0.000000
# 4           NCD19         8.93          Low Fat         0.000000
#
#                Item_Type  Item_MRP Outlet_Identifier  \
# 0                  Dairy  249.8092            OUT049
# 1            Soft Drinks   48.2692            OUT018
# 2                   Meat  141.6180            OUT049
# 3  Fruits and Vegetables  182.0950            OUT010
# 4              Household   53.8614            OUT013
#
#    Outlet_Establishment_Year Outlet_Size Outlet_Location_Type  \
# 0                       1999      Medium               Tier 1
# 1                       2009      Medium               Tier 3
# 2                       1999      Medium               Tier 1
# 3                       1998         NaN               Tier 3
# 4                       1987        High               Tier 3
#
#          Outlet_Type  Item_Outlet_Sales
# 0  Supermarket Type1          3735.1380
# 1  Supermarket Type2           443.4228
# 2  Supermarket Type1          2097.2700
# 3      Grocery Store           732.3800
# 4  Supermarket Type1           994.7052

# %%
df.shape
# Out:
# (8523, 12)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 8523 entries, 0 to 8522
# Data columns (total 12 columns):
#  #   Column                     Non-Null Count  Dtype
# ---  ------                     --------------  -----
#  0   Item_Identifier            8523 non-null   object
#  1   Item_Weight                7060 non-null   float64
#  2   Item_Fat_Content           8523 non-null   object
#  3   Item_Visibility            8523 non-null   float64
#  4   Item_Type                  8523 non-null   object
#  5   Item_MRP                   8523 non-null   float64
#  6   Outlet_Identifier          8523 non-null   object
#  7   Outlet_Establishment_Year  8523 non-null   int64
#  8   Outlet_Size                6113 non-null   object
#  9   Outlet_Location_Type       8523 non-null   object
#  10  Outlet_Type                8523 non-null   object
#  11  Item_Outlet_Sales          8523 non-null   float64
# dtypes: float64(4), int64(1), object(7)
# memory usage: 799.2+ KB

# %% [markdown]
# shuffling and deviding data

# %%
from sklearn.utils import shuffle
df=shuffle(df,random_state=42)
#dividing
div=int(df.shape[0]/4)
train=df[:3*div+1:]
test=df[div+2:]

# %%
train.head()
# Out:
#      Item_Identifier  Item_Weight Item_Fat_Content  Item_Visibility  \
# 7503           FDI28       14.300          Low Fat         0.026300
# 2957           NCM17        7.930          Low Fat         0.071136
# 7031           FDC14       14.500          Regular         0.041313
# 1084           DRC36          NaN          Regular         0.044767
# 856            FDS27       10.195          Regular         0.012456
#
#                Item_Type  Item_MRP Outlet_Identifier  \
# 7503        Frozen Foods   79.4302            OUT013
# 2957  Health and Hygiene   42.7086            OUT046
# 7031              Canned   42.0454            OUT049
# 1084         Soft Drinks  173.7054            OUT027
# 856                 Meat  197.5110            OUT035
#
#       Outlet_Establishment_Year Outlet_Size Outlet_Location_Type  \
# 7503                       1987        High               Tier 3
# 2957                       1997       Small               Tier 1
# 7031                       1999      Medium               Tier 1
# 1084                       1985      Medium               Tier 3
# 856                        2004       Small               Tier 2
#
#             Outlet_Type  Item_Outlet_Sales
# 7503  Supermarket Type1          1743.0644
# 2957  Supermarket Type1           356.8688
# 7031  Supermarket Type1           377.5086
# 1084  Supermarket Type3          5778.4782
# 856   Supermarket Type1          2356.9320

# %%
test.head()
# Out:
#      Item_Identifier  Item_Weight Item_Fat_Content  Item_Visibility  \
# 7510           FDV57       15.250          Regular         0.000000
# 5828           FDM27       12.350          Regular         0.158716
# 5327           FDG24        7.975          Low Fat         0.014628
# 4810           FDD05       19.350          Low Fat         0.016645
# 4377           FDP40          NaN          Regular         0.060155
#
#          Item_Type  Item_MRP Outlet_Identifier  Outlet_Establishment_Year  \
# 7510   Snack Foods  179.7660            OUT018                       2009
# 5828          Meat  157.2946            OUT049                       1999
# 5327  Baking Goods   82.3250            OUT035                       2004
# 4810  Frozen Foods  120.9098            OUT045                       2002
# 4377  Frozen Foods  110.1544            OUT019                       1985
#
#      Outlet_Size Outlet_Location_Type        Outlet_Type  Item_Outlet_Sales
# 7510      Medium               Tier 3  Supermarket Type2          3056.0220
# 5828      Medium               Tier 1  Supermarket Type1          1577.9460
# 5327       Small               Tier 2  Supermarket Type1          1331.6000
# 4810         NaN               Tier 2  Supermarket Type1          1687.1372
# 4377       Small               Tier 1      Grocery Store           111.8544

# %% [markdown]
# # SIMPLE MEAN ERROR

# %%
#ADDING NEW COLUMN AS MEAN OF ITEM_OUTLET_SALES
test['Simple_mean']=test['Item_Outlet_Sales'].mean()
# Out:
# C:\Users\hvika\anaconda3.x\lib\site-packages\ipykernel_launcher.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy

# %%
from sklearn.metrics  import mean_absolute_error as MAE
simple_mean_error=MAE(test['Item_Outlet_Sales'],test['Simple_mean'])
simple_mean_error
# Out:
# 1360.2120417960446

# %%
out_type=pd.pivot_table(train,values='Item_Outlet_Sales',index=['Outlet_Type'],aggfunc=np.mean)
out_type
# Out:
#                    Item_Outlet_Sales
# Outlet_Type
# Grocery Store             339.713738
# Supermarket Type1        2269.172538
# Supermarket Type2        1961.889047
# Supermarket Type3        3735.211455
